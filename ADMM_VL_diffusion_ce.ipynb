# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import math

from unet import UNetModel
from diffusion import GaussianDiffusion

import tqdm
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('image', cmap='gray')

# %% [markdown]
# # Load Dataset

# %%
# Load MNIST dataset
device = torch.device('cuda:0')
batch_size = 128

transforms = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Pad(2),
    torchvision.transforms.Normalize(0.5, 0.5),
])
mnist_train = torchvision.datasets.MNIST(root='data/', train=True, transform=transforms, download=True)
data_loader = torch.utils.data.DataLoader(mnist_train, batch_size=batch_size, shuffle=True, num_workers=4)

for batch in data_loader:
    img, labels = batch
    break
    
fig, ax = plt.subplots(1, 4, figsize=(15,15))
for i in range(4):
    ax[i].imshow(img[i,0,:,:].numpy())
    ax[i].set_title(str(labels[i].item()))
plt.show()

# %% [markdown]
# # Load Model

# %%
# Save/Load model
#torch.save(net.state_dict(), 'models/mnist_unet.pth')
#print('Saved model')

net = UNetModel(image_size=32, in_channels=1, out_channels=1, 
                model_channels=64, num_res_blocks=2, channel_mult=(1,2,3,4),
                attention_resolutions=[8,4], num_heads=4).to(device)
net.load_state_dict(torch.load('models/mnist_unet.pth'))
net.to(device)
net.train()
print('Loaded model')
# Out:
# Loaded model
# /tmp/ipykernel_28767/1173412691.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(torch.load('models/mnist_unet.pth'))

# %% [markdown]
# # Baseline: Direct Sampling

# %%
# Sample from the learned diffusion process
diffusion = GaussianDiffusion(T=1000, schedule='linear')

with torch.no_grad():
    net.eval()
    x = diffusion.inverse(net, shape=(1,32,32), device=device)
    net.train()

plt.figure(figsize=(5,5))
plt.imshow(x.cpu().numpy()[0,0,:,:], vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# # Baseline: No Auxiliary Loss

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import tqdm
import math
import matplotlib.pyplot as plt
import torchvision.transforms.functional as TF

# Assume net and diffusion are defined elsewhere

# Inference Model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.img = nn.Parameter(torch.randn(1, 1, 32, 32))
        self.img.requires_grad = True

    def encode(self):
        return self.img

x_admm = Model().to(device)
opt_x = torch.optim.Adam([x_admm.img], lr=0.01)

# Initialize z and u
z = nn.Parameter(x_admm.img.clone().detach()).to(device)
opt_z = torch.optim.Adam([z], lr=0.01)

u = torch.zeros_like(x_admm.img).to(device)

rho = 1e-8  # Penalty parameter
lambda_param = 0.01  # Weight for asymmetry loss

diffusion = GaussianDiffusion(T=1000, schedule='linear')
net.train()

steps = 1000
bar = tqdm.tqdm(range(steps))
losses = []
update_every = 50

for i in bar:
    # Select t
    t = ((steps - i) + (steps - i) // 4 * math.cos(i / 50)) / steps * diffusion.T
    t = np.array([t]).astype(int)
    t = np.clip(t, 1, diffusion.T)

    # x-update
    sample_img = x_admm.encode()
    xt, epsilon = diffusion.sample(sample_img, t)
    t = torch.from_numpy(t).float().view(sample_img.shape[0])
    epsilon_pred = net(xt.float(), t.to(device))
    loss_denoise = F.mse_loss(epsilon_pred, epsilon)

    loss_x = loss_denoise

    opt_x.zero_grad()
    loss_x.backward()
    opt_x.step()

    # Logging
    total_loss = loss_x.item() #+ loss_z.item()
    losses.append(total_loss)
    if i % update_every == 0:
        bar.set_postfix({'Loss': np.mean(losses)})
        losses = []

    # Visualize sample
    if (i + 1) % 100 == 0 or i == 0:
        with torch.no_grad():
            fig, ax = plt.subplots(1, 1, figsize=(5, 5))
            img_to_show = x_admm.encode()[0].detach().cpu().numpy().transpose([1, 2, 0])
            ax.imshow(img_to_show, vmin=-1, vmax=1)
            ax.set_title('Inferred sample')
            plt.show()
# Out:
# ...
# 100%|██████████| 1000/1000 [01:01<00:00, 16.19it/s, Loss=0.0152]

# %% [markdown]
# # Train Classifier

# %%
# Train classifier
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 32, 3, 2, 1)
        self.conv2 = nn.Conv2d(32, 32, 3, 2, 1)
        self.conv3 = nn.Conv2d(32, 32, 3, 2, 1)
        self.out = nn.Linear(4*4*32, 10)
    
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = self.out(x.flatten(1))
        
        return x
    
# Train network
class_net = Classifier().to(device)
class_opt = torch.optim.Adam(class_net.parameters(), lr=1e-4)

target_label = 6 # Digit to distinguish
epochs = 5
update_every = 100
for e in range(epochs):
    print(f'Epoch [{e+1}/{epochs}]')
    
    losses = []
    batch_bar = tqdm.tqdm(data_loader)
    for i, batch in enumerate(batch_bar):
        img, labels = batch
        
        # Pass through network
        out = class_net(img.float().to(device))
        
        # Compute loss and backprop
        loss = F.cross_entropy(out.squeeze(-1), labels.to(device))
        
        class_opt.zero_grad()
        loss.backward()
        class_opt.step()
        
        losses.append(loss.item())
        if i % update_every == 0:
            batch_bar.set_postfix({'Loss': np.mean(losses)})
            losses = []
            
    batch_bar.set_postfix({'Loss': np.mean(losses)})
    losses = []
    
    plt.figure(figsize=(5,5))
    plt.imshow(img.numpy()[0,0,:,:])
    plt.title(f'Pred Class: {np.argmax(out[0].detach().cpu().numpy())}')
    plt.show()
# Out:
# Epoch [1/5]
# 100%|██████████| 469/469 [00:02<00:00, 164.85it/s, Loss=0.543]
# Epoch [2/5]
# 100%|██████████| 469/469 [00:02<00:00, 180.55it/s, Loss=0.373]
# Epoch [3/5]
# 100%|██████████| 469/469 [00:02<00:00, 177.64it/s, Loss=0.307]
# Epoch [4/5]
# 100%|██████████| 469/469 [00:02<00:00, 179.28it/s, Loss=0.262]
# Epoch [5/5]
# 100%|██████████| 469/469 [00:02<00:00, 180.08it/s, Loss=0.224]

# %% [markdown]
# # ADMM: Target 1

# %%
torch.manual_seed(42)
np.random.seed(42)

# Assume net and diffusion are defined elsewhere

# Inference Model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.img = nn.Parameter(torch.randn(1, 1, 32, 32))
        self.img.requires_grad = True

    def encode(self):
        return self.img

x_admm = Model().to(device)
opt_x = torch.optim.Adam([x_admm.img], lr=0.01)

# Initialize z and u
z = nn.Parameter(x_admm.img.clone().detach()).to(device)
opt_z = torch.optim.Adam([z], lr=0.01)

u = torch.zeros_like(x_admm.img).to(device)

rho = 1e-6  # Penalty parameter
lambda_param = 1e2  # Weight for asymmetry loss

diffusion = GaussianDiffusion(T=1000, schedule='linear')
net.eval()
class_net.eval()


steps = 1000
inner_steps = 10
bar = tqdm.tqdm(range(steps))
losses = []
update_every = 200

target = torch.Tensor([]).long().to(device)

for i in bar:
    # Select t
    t = steps - i
    #t = ((steps - i) + (steps - i) // 4 * math.cos(i / 50)) / steps * diffusion.T
    t = np.array([t]).astype(int)
    t = np.clip(t, 1, diffusion.T)

    # x-update
    sample_img = x_admm.encode()
    xt, epsilon = diffusion.sample(sample_img, t)
    t = torch.from_numpy(t).float().view(sample_img.shape[0])
    epsilon_pred = net(xt.float(), t.to(device))
    loss_denoise = F.mse_loss(epsilon_pred, epsilon)

    loss_x = loss_denoise + (rho / 2) * torch.norm(x_admm.img - z + u) ** 2

    opt_x.zero_grad()
    loss_x.backward()
    opt_x.step()

    # z-update
    sample_img_clipped_z = z  #torch.clamp(z, -1, 1)
    for _ in range(inner_steps):
        pred_class = class_net(sample_img_clipped_z)
        aux_loss = F.cross_entropy(pred_class, target)
        loss_z = 0.01*(steps-i)/steps * lambda_param * aux_loss + (rho / 2) * torch.norm(x_admm.img.detach() - sample_img_clipped_z + u) ** 2

        opt_z.zero_grad()
        loss_z.backward()
        opt_z.step()

    # u-update
    u = u + x_admm.img.detach() - sample_img_clipped_z.detach()

    # Logging
    total_loss = loss_x.item() + loss_z.item()
    losses.append(total_loss)
    if i % update_every == 0:
        bar.set_postfix({'Loss': np.mean(losses)})
        losses = []

    # Visualize sample
    if (i + 1) % steps == 0:
        with torch.no_grad():
            fig, ax = plt.subplots(1, 1, figsize=(5, 5))
            img_to_show = x_admm.encode()[0].detach().cpu().numpy().transpose([1, 2, 0])
            ax.imshow(img_to_show, vmin=-1, vmax=1)
            ax.set_title('Inferred sample')
            plt.show()
# Out:
# ...
# 100%|██████████| 1000/1000 [01:18<00:00, 12.81it/s, Loss=1.27]

# %% [markdown]
# # ADMM: Target 2

# %%
torch.manual_seed(42)
np.random.seed(42)

# Assume net and diffusion are defined elsewhere

# Inference Model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.img = nn.Parameter(torch.randn(1, 1, 32, 32))
        self.img.requires_grad = True

    def encode(self):
        return self.img

x_admm = Model().to(device)
opt_x = torch.optim.Adam([x_admm.img], lr=0.01)

# Initialize z and u
z = nn.Parameter(x_admm.img.clone().detach()).to(device)
opt_z = torch.optim.Adam([z], lr=0.01)

u = torch.zeros_like(x_admm.img).to(device)

rho = 1e-6  # Penalty parameter
lambda_param = 1e2  # Weight for asymmetry loss

diffusion = GaussianDiffusion(T=1000, schedule='linear')
net.eval()
class_net.eval()


steps = 1000
inner_steps = 10
bar = tqdm.tqdm(range(steps))
losses = []
update_every = 200

target = torch.Tensor([2]).long().to(device)

for i in bar:
    # Select t
    t = steps - i
    #t = ((steps - i) + (steps - i) // 4 * math.cos(i / 50)) / steps * diffusion.T
    t = np.array([t]).astype(int)
    t = np.clip(t, 1, diffusion.T)

    # x-update
    sample_img = x_admm.encode()
    xt, epsilon = diffusion.sample(sample_img, t)
    t = torch.from_numpy(t).float().view(sample_img.shape[0])
    epsilon_pred = net(xt.float(), t.to(device))
    loss_denoise = F.mse_loss(epsilon_pred, epsilon)

    loss_x = loss_denoise + (rho / 2) * torch.norm(x_admm.img - z + u) ** 2

    opt_x.zero_grad()
    loss_x.backward()
    opt_x.step()

    # z-update
    sample_img_clipped_z = z  #torch.clamp(z, -1, 1)
    for _ in range(inner_steps):
        pred_class = class_net(sample_img_clipped_z)
        aux_loss = F.cross_entropy(pred_class, target)
        loss_z = 0.01*(steps-i)/steps * lambda_param * aux_loss + (rho / 2) * torch.norm(x_admm.img.detach() - sample_img_clipped_z + u) ** 2

        opt_z.zero_grad()
        loss_z.backward()
        opt_z.step()

    # u-update
    u = u + x_admm.img.detach() - sample_img_clipped_z.detach()

    # Logging
    total_loss = loss_x.item() + loss_z.item()
    losses.append(total_loss)
    if i % update_every == 0:
        bar.set_postfix({'Loss': np.mean(losses)})
        losses = []

    # Visualize sample
    if (i + 1) % steps == 0:
        with torch.no_grad():
            fig, ax = plt.subplots(1, 1, figsize=(5, 5))
            img_to_show = x_admm.encode()[0].detach().cpu().numpy().transpose([1, 2, 0])
            ax.imshow(img_to_show, vmin=-1, vmax=1)
            ax.set_title('Inferred sample')
            plt.show()
# Out:
# ...
# 100%|██████████| 1000/1000 [01:22<00:00, 12.14it/s, Loss=0.529]

# %% [markdown]
# # ADMM: Target 3

# %%
torch.manual_seed(42)
np.random.seed(42)

# Assume net and diffusion are defined elsewhere

# Inference Model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.img = nn.Parameter(torch.randn(1, 1, 32, 32))
        self.img.requires_grad = True

    def encode(self):
        return self.img

x_admm = Model().to(device)
opt_x = torch.optim.Adam([x_admm.img], lr=0.01)

# Initialize z and u
z = nn.Parameter(x_admm.img.clone().detach()).to(device)
opt_z = torch.optim.Adam([z], lr=0.01)

u = torch.zeros_like(x_admm.img).to(device)

rho = 1e-6  # Penalty parameter
lambda_param = 1e2  # Weight for asymmetry loss

diffusion = GaussianDiffusion(T=1000, schedule='linear')
net.eval()
class_net.eval()


steps = 1000
inner_steps = 10
bar = tqdm.tqdm(range(steps))
losses = []
update_every = 200

target = torch.Tensor([3]).long().to(device)

for i in bar:
    # Select t
    t = steps - i
    #t = ((steps - i) + (steps - i) // 4 * math.cos(i / 50)) / steps * diffusion.T
    t = np.array([t]).astype(int)
    t = np.clip(t, 1, diffusion.T)

    # x-update
    sample_img = x_admm.encode()
    xt, epsilon = diffusion.sample(sample_img, t)
    t = torch.from_numpy(t).float().view(sample_img.shape[0])
    epsilon_pred = net(xt.float(), t.to(device))
    loss_denoise = F.mse_loss(epsilon_pred, epsilon)

    loss_x = loss_denoise + (rho / 2) * torch.norm(x_admm.img - z + u) ** 2

    opt_x.zero_grad()
    loss_x.backward()
    opt_x.step()

    # z-update
    sample_img_clipped_z = z  #torch.clamp(z, -1, 1)
    for _ in range(inner_steps):
        pred_class = class_net(sample_img_clipped_z)
        aux_loss = F.cross_entropy(pred_class, target)
        loss_z = 0.01*(steps-i)/steps * lambda_param * aux_loss + (rho / 2) * torch.norm(x_admm.img.detach() - sample_img_clipped_z + u) ** 2

        opt_z.zero_grad()
        loss_z.backward()
        opt_z.step()

    # u-update
    u = u + x_admm.img.detach() - sample_img_clipped_z.detach()

    # Logging
    total_loss = loss_x.item() + loss_z.item()
    losses.append(total_loss)
    if i % update_every == 0:
        bar.set_postfix({'Loss': np.mean(losses)})
        losses = []

    # Visualize sample
    if (i + 1) % steps == 0:
        with torch.no_grad():
            fig, ax = plt.subplots(1, 1, figsize=(5, 5))
            img_to_show = x_admm.encode()[0].detach().cpu().numpy().transpose([1, 2, 0])
            ax.imshow(img_to_show, vmin=-1, vmax=1)
            ax.set_title('Inferred sample')
            plt.show()
# Out:
# ...
# 100%|██████████| 1000/1000 [01:17<00:00, 12.90it/s, Loss=0.271]

# %% [markdown]
# # ADMM: Target 4

# %%
torch.manual_seed(42)
np.random.seed(42)

# Assume net and diffusion are defined elsewhere

# Inference Model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.img = nn.Parameter(torch.randn(1, 1, 32, 32))
        self.img.requires_grad = True

    def encode(self):
        return self.img

x_admm = Model().to(device)
opt_x = torch.optim.Adam([x_admm.img], lr=0.01)

# Initialize z and u
z = nn.Parameter(x_admm.img.clone().detach()).to(device)
opt_z = torch.optim.Adam([z], lr=0.01)

u = torch.zeros_like(x_admm.img).to(device)

rho = 1e-6  # Penalty parameter
lambda_param = 1e2  # Weight for asymmetry loss

diffusion = GaussianDiffusion(T=1000, schedule='linear')
net.eval()
class_net.eval()


steps = 1000
inner_steps = 10
bar = tqdm.tqdm(range(steps))
losses = []
update_every = 200

target = torch.Tensor([4]).long().to(device)

for i in bar:
    # Select t
    t = steps - i
    #t = ((steps - i) + (steps - i) // 4 * math.cos(i / 50)) / steps * diffusion.T
    t = np.array([t]).astype(int)
    t = np.clip(t, 1, diffusion.T)

    # x-update
    sample_img = x_admm.encode()
    xt, epsilon = diffusion.sample(sample_img, t)
    t = torch.from_numpy(t).float().view(sample_img.shape[0])
    epsilon_pred = net(xt.float(), t.to(device))
    loss_denoise = F.mse_loss(epsilon_pred, epsilon)

    loss_x = loss_denoise + (rho / 2) * torch.norm(x_admm.img - z + u) ** 2

    opt_x.zero_grad()
    loss_x.backward()
    opt_x.step()

    # z-update
    sample_img_clipped_z = z  #torch.clamp(z, -1, 1)
    for _ in range(inner_steps):
        pred_class = class_net(sample_img_clipped_z)
        aux_loss = F.cross_entropy(pred_class, target)
        loss_z = 0.01*(steps-i)/steps * lambda_param * aux_loss + (rho / 2) * torch.norm(x_admm.img.detach() - sample_img_clipped_z + u) ** 2

        opt_z.zero_grad()
        loss_z.backward()
        opt_z.step()

    # u-update
    u = u + x_admm.img.detach() - sample_img_clipped_z.detach()

    # Logging
    total_loss = loss_x.item() + loss_z.item()
    losses.append(total_loss)
    if i % update_every == 0:
        bar.set_postfix({'Loss': np.mean(losses)})
        losses = []

    # Visualize sample
    if (i + 1) % steps == 0:
        with torch.no_grad():
            fig, ax = plt.subplots(1, 1, figsize=(5, 5))
            img_to_show = x_admm.encode()[0].detach().cpu().numpy().transpose([1, 2, 0])
            ax.imshow(img_to_show, vmin=-1, vmax=1)
            ax.set_title('Inferred sample')
            plt.show()
# Out:
# ...
# 100%|██████████| 1000/1000 [01:18<00:00, 12.81it/s, Loss=2.01]

# %% [markdown]
# # ADMM: Target 5

# %%
torch.manual_seed(42)
np.random.seed(42)

# Assume net and diffusion are defined elsewhere

# Inference Model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.img = nn.Parameter(torch.randn(1, 1, 32, 32))
        self.img.requires_grad = True

    def encode(self):
        return self.img

x_admm = Model().to(device)
opt_x = torch.optim.Adam([x_admm.img], lr=0.01)

# Initialize z and u
z = nn.Parameter(x_admm.img.clone().detach()).to(device)
opt_z = torch.optim.Adam([z], lr=0.01)

u = torch.zeros_like(x_admm.img).to(device)

rho = 1e-6  # Penalty parameter
lambda_param = 1e2  # Weight for asymmetry loss

diffusion = GaussianDiffusion(T=1000, schedule='linear')
net.eval()
class_net.eval()


steps = 1000
inner_steps = 10
bar = tqdm.tqdm(range(steps))
losses = []
update_every = 200

target = torch.Tensor([5]).long().to(device)

for i in bar:
    # Select t
    t = steps - i
    #t = ((steps - i) + (steps - i) // 4 * math.cos(i / 50)) / steps * diffusion.T
    t = np.array([t]).astype(int)
    t = np.clip(t, 1, diffusion.T)

    # x-update
    sample_img = x_admm.encode()
    xt, epsilon = diffusion.sample(sample_img, t)
    t = torch.from_numpy(t).float().view(sample_img.shape[0])
    epsilon_pred = net(xt.float(), t.to(device))
    loss_denoise = F.mse_loss(epsilon_pred, epsilon)

    loss_x = loss_denoise + (rho / 2) * torch.norm(x_admm.img - z + u) ** 2

    opt_x.zero_grad()
    loss_x.backward()
    opt_x.step()

    # z-update
    sample_img_clipped_z = z  #torch.clamp(z, -1, 1)
    for _ in range(inner_steps):
        pred_class = class_net(sample_img_clipped_z)
        aux_loss = F.cross_entropy(pred_class, target)
        loss_z = 0.01*(steps-i)/steps * lambda_param * aux_loss + (rho / 2) * torch.norm(x_admm.img.detach() - sample_img_clipped_z + u) ** 2

        opt_z.zero_grad()
        loss_z.backward()
        opt_z.step()

    # u-update
    u = u + x_admm.img.detach() - sample_img_clipped_z.detach()

    # Logging
    total_loss = loss_x.item() + loss_z.item()
    losses.append(total_loss)
    if i % update_every == 0:
        bar.set_postfix({'Loss': np.mean(losses)})
        losses = []

    # Visualize sample
    if (i + 1) % steps == 0:
        with torch.no_grad():
            fig, ax = plt.subplots(1, 1, figsize=(5, 5))
            img_to_show = x_admm.encode()[0].detach().cpu().numpy().transpose([1, 2, 0])
            ax.imshow(img_to_show, vmin=-1, vmax=1)
            ax.set_title('Inferred sample')
            plt.show()
# Out:
# ...
# 100%|██████████| 1000/1000 [01:17<00:00, 12.91it/s, Loss=1.21]

# %% [markdown]
# # ADMM: Target 6

# %%
torch.manual_seed(42)
np.random.seed(42)

# Assume net and diffusion are defined elsewhere

# Inference Model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.img = nn.Parameter(torch.randn(1, 1, 32, 32))
        self.img.requires_grad = True

    def encode(self):
        return self.img

x_admm = Model().to(device)
opt_x = torch.optim.Adam([x_admm.img], lr=0.01)

# Initialize z and u
z = nn.Parameter(x_admm.img.clone().detach()).to(device)
opt_z = torch.optim.Adam([z], lr=0.01)

u = torch.zeros_like(x_admm.img).to(device)

rho = 1e-6  # Penalty parameter
lambda_param = 1e2  # Weight for asymmetry loss

diffusion = GaussianDiffusion(T=1000, schedule='linear')
net.eval()
class_net.eval()


steps = 1000
inner_steps = 10
bar = tqdm.tqdm(range(steps))
losses = []
update_every = 200

target = torch.Tensor([6]).long().to(device)

for i in bar:
    # Select t
    t = steps - i
    #t = ((steps - i) + (steps - i) // 4 * math.cos(i / 50)) / steps * diffusion.T
    t = np.array([t]).astype(int)
    t = np.clip(t, 1, diffusion.T)

    # x-update
    sample_img = x_admm.encode()
    xt, epsilon = diffusion.sample(sample_img, t)
    t = torch.from_numpy(t).float().view(sample_img.shape[0])
    epsilon_pred = net(xt.float(), t.to(device))
    loss_denoise = F.mse_loss(epsilon_pred, epsilon)

    loss_x = loss_denoise + (rho / 2) * torch.norm(x_admm.img - z + u) ** 2

    opt_x.zero_grad()
    loss_x.backward()
    opt_x.step()

    # z-update
    sample_img_clipped_z = z  #torch.clamp(z, -1, 1)
    for _ in range(inner_steps):
        pred_class = class_net(sample_img_clipped_z)
        aux_loss = F.cross_entropy(pred_class, target)
        loss_z = 0.01*(steps-i)/steps * lambda_param * aux_loss + (rho / 2) * torch.norm(x_admm.img.detach() - sample_img_clipped_z + u) ** 2

        opt_z.zero_grad()
        loss_z.backward()
        opt_z.step()

    # u-update
    u = u + x_admm.img.detach() - sample_img_clipped_z.detach()

    # Logging
    total_loss = loss_x.item() + loss_z.item()
    losses.append(total_loss)
    if i % update_every == 0:
        bar.set_postfix({'Loss': np.mean(losses)})
        losses = []

    # Visualize sample
    if (i + 1) % steps == 0:
        with torch.no_grad():
            fig, ax = plt.subplots(1, 1, figsize=(5, 5))
            img_to_show = x_admm.encode()[0].detach().cpu().numpy().transpose([1, 2, 0])
            ax.imshow(img_to_show, vmin=-1, vmax=1)
            ax.set_title('Inferred sample')
            plt.show()
# Out:
# ...
# 100%|██████████| 1000/1000 [01:16<00:00, 13.03it/s, Loss=1.97]

# %% [markdown]
# # ADMM: Target 7

# %%
torch.manual_seed(42)
np.random.seed(42)

# Assume net and diffusion are defined elsewhere

# Inference Model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.img = nn.Parameter(torch.randn(1, 1, 32, 32))
        self.img.requires_grad = True

    def encode(self):
        return self.img

x_admm = Model().to(device)
opt_x = torch.optim.Adam([x_admm.img], lr=0.01)

# Initialize z and u
z = nn.Parameter(x_admm.img.clone().detach()).to(device)
opt_z = torch.optim.Adam([z], lr=0.01)

u = torch.zeros_like(x_admm.img).to(device)

rho = 1e-6  # Penalty parameter
lambda_param = 1e2  # Weight for asymmetry loss

diffusion = GaussianDiffusion(T=1000, schedule='linear')
net.eval()
class_net.eval()


steps = 1000
inner_steps = 10
bar = tqdm.tqdm(range(steps))
losses = []
update_every = 200

target = torch.Tensor([7]).long().to(device)

for i in bar:
    # Select t
    t = steps - i
    #t = ((steps - i) + (steps - i) // 4 * math.cos(i / 50)) / steps * diffusion.T
    t = np.array([t]).astype(int)
    t = np.clip(t, 1, diffusion.T)

    # x-update
    sample_img = x_admm.encode()
    xt, epsilon = diffusion.sample(sample_img, t)
    t = torch.from_numpy(t).float().view(sample_img.shape[0])
    epsilon_pred = net(xt.float(), t.to(device))
    loss_denoise = F.mse_loss(epsilon_pred, epsilon)

    loss_x = loss_denoise + (rho / 2) * torch.norm(x_admm.img - z + u) ** 2

    opt_x.zero_grad()
    loss_x.backward()
    opt_x.step()

    # z-update
    sample_img_clipped_z = z  #torch.clamp(z, -1, 1)
    for _ in range(inner_steps):
        pred_class = class_net(sample_img_clipped_z)
        aux_loss = F.cross_entropy(pred_class, target)
        loss_z = 0.01*(steps-i)/steps * lambda_param * aux_loss + (rho / 2) * torch.norm(x_admm.img.detach() - sample_img_clipped_z + u) ** 2

        opt_z.zero_grad()
        loss_z.backward()
        opt_z.step()

    # u-update
    u = u + x_admm.img.detach() - sample_img_clipped_z.detach()

    # Logging
    total_loss = loss_x.item() + loss_z.item()
    losses.append(total_loss)
    if i % update_every == 0:
        bar.set_postfix({'Loss': np.mean(losses)})
        losses = []

    # Visualize sample
    if (i + 1) % steps == 0:
        with torch.no_grad():
            fig, ax = plt.subplots(1, 1, figsize=(5, 5))
            img_to_show = x_admm.encode()[0].detach().cpu().numpy().transpose([1, 2, 0])
            ax.imshow(img_to_show, vmin=-1, vmax=1)
            ax.set_title('Inferred sample')
            plt.show()
# Out:
# ...
# 100%|██████████| 1000/1000 [01:17<00:00, 12.86it/s, Loss=1.24]

# %% [markdown]
# # ADMM: Target 8

# %%
torch.manual_seed(42)
np.random.seed(42)

# Assume net and diffusion are defined elsewhere

# Inference Model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.img = nn.Parameter(torch.randn(1, 1, 32, 32))
        self.img.requires_grad = True

    def encode(self):
        return self.img

x_admm = Model().to(device)
opt_x = torch.optim.Adam([x_admm.img], lr=0.01)

# Initialize z and u
z = nn.Parameter(x_admm.img.clone().detach()).to(device)
opt_z = torch.optim.Adam([z], lr=0.01)

u = torch.zeros_like(x_admm.img).to(device)

rho = 1e-6  # Penalty parameter
lambda_param = 1e2  # Weight for asymmetry loss

diffusion = GaussianDiffusion(T=1000, schedule='linear')
net.eval()
class_net.eval()


steps = 1000
inner_steps = 10
bar = tqdm.tqdm(range(steps))
losses = []
update_every = 200

target = torch.Tensor([8]).long().to(device)

for i in bar:
    # Select t
    t = steps - i
    #t = ((steps - i) + (steps - i) // 4 * math.cos(i / 50)) / steps * diffusion.T
    t = np.array([t]).astype(int)
    t = np.clip(t, 1, diffusion.T)

    # x-update
    sample_img = x_admm.encode()
    xt, epsilon = diffusion.sample(sample_img, t)
    t = torch.from_numpy(t).float().view(sample_img.shape[0])
    epsilon_pred = net(xt.float(), t.to(device))
    loss_denoise = F.mse_loss(epsilon_pred, epsilon)

    loss_x = loss_denoise + (rho / 2) * torch.norm(x_admm.img - z + u) ** 2

    opt_x.zero_grad()
    loss_x.backward()
    opt_x.step()

    # z-update
    sample_img_clipped_z = z  #torch.clamp(z, -1, 1)
    for _ in range(inner_steps):
        pred_class = class_net(sample_img_clipped_z)
        aux_loss = F.cross_entropy(pred_class, target)
        loss_z = 0.01*(steps-i)/steps * lambda_param * aux_loss + (rho / 2) * torch.norm(x_admm.img.detach() - sample_img_clipped_z + u) ** 2

        opt_z.zero_grad()
        loss_z.backward()
        opt_z.step()

    # u-update
    u = u + x_admm.img.detach() - sample_img_clipped_z.detach()

    # Logging
    total_loss = loss_x.item() + loss_z.item()
    losses.append(total_loss)
    if i % update_every == 0:
        bar.set_postfix({'Loss': np.mean(losses)})
        losses = []

    # Visualize sample
    if (i + 1) % steps == 0:
        with torch.no_grad():
            fig, ax = plt.subplots(1, 1, figsize=(5, 5))
            img_to_show = x_admm.encode()[0].detach().cpu().numpy().transpose([1, 2, 0])
            ax.imshow(img_to_show, vmin=-1, vmax=1)
            ax.set_title('Inferred sample')
            plt.show()
# Out:
# ...
# 100%|██████████| 1000/1000 [01:20<00:00, 12.38it/s, Loss=1.38]

# %% [markdown]
# # ADMM: Target 9

# %%
torch.manual_seed(42)
np.random.seed(42)

# Assume net and diffusion are defined elsewhere

# Inference Model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.img = nn.Parameter(torch.randn(1, 1, 32, 32))
        self.img.requires_grad = True

    def encode(self):
        return self.img

x_admm = Model().to(device)
opt_x = torch.optim.Adam([x_admm.img], lr=0.01)

# Initialize z and u
z = nn.Parameter(x_admm.img.clone().detach()).to(device)
opt_z = torch.optim.Adam([z], lr=0.01)

u = torch.zeros_like(x_admm.img).to(device)

rho = 1e-6  # Penalty parameter
lambda_param = 1e2  # Weight for asymmetry loss

diffusion = GaussianDiffusion(T=1000, schedule='linear')
net.eval()
class_net.eval()


steps = 1000
inner_steps = 10
bar = tqdm.tqdm(range(steps))
losses = []
update_every = 200

target = torch.Tensor([9]).long().to(device)

for i in bar:
    # Select t
    t = steps - i
    #t = ((steps - i) + (steps - i) // 4 * math.cos(i / 50)) / steps * diffusion.T
    t = np.array([t]).astype(int)
    t = np.clip(t, 1, diffusion.T)

    # x-update
    sample_img = x_admm.encode()
    xt, epsilon = diffusion.sample(sample_img, t)
    t = torch.from_numpy(t).float().view(sample_img.shape[0])
    epsilon_pred = net(xt.float(), t.to(device))
    loss_denoise = F.mse_loss(epsilon_pred, epsilon)

    loss_x = loss_denoise + (rho / 2) * torch.norm(x_admm.img - z + u) ** 2

    opt_x.zero_grad()
    loss_x.backward()
    opt_x.step()

    # z-update
    sample_img_clipped_z = z  #torch.clamp(z, -1, 1)
    for _ in range(inner_steps):
        pred_class = class_net(sample_img_clipped_z)
        aux_loss = F.cross_entropy(pred_class, target)
        loss_z = 0.01*(steps-i)/steps * lambda_param * aux_loss + (rho / 2) * torch.norm(x_admm.img.detach() - sample_img_clipped_z + u) ** 2

        opt_z.zero_grad()
        loss_z.backward()
        opt_z.step()

    # u-update
    u = u + x_admm.img.detach() - sample_img_clipped_z.detach()

    # Logging
    total_loss = loss_x.item() + loss_z.item()
    losses.append(total_loss)
    if i % update_every == 0:
        bar.set_postfix({'Loss': np.mean(losses)})
        losses = []

    # Visualize sample
    if (i + 1) % steps == 0:
        with torch.no_grad():
            fig, ax = plt.subplots(1, 1, figsize=(5, 5))
            img_to_show = x_admm.encode()[0].detach().cpu().numpy().transpose([1, 2, 0])
            ax.imshow(img_to_show, vmin=-1, vmax=1)
            ax.set_title('Inferred sample')
            plt.show()
# Out:
# ...
# 100%|██████████| 1000/1000 [01:21<00:00, 12.25it/s, Loss=1.78]

# %% [markdown]
# # ADMM: Target 0

# %%
torch.manual_seed(42)
np.random.seed(42)

# Assume net and diffusion are defined elsewhere

# Inference Model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.img = nn.Parameter(torch.randn(1, 1, 32, 32))
        self.img.requires_grad = True

    def encode(self):
        return self.img

x_admm = Model().to(device)
opt_x = torch.optim.Adam([x_admm.img], lr=0.01)

# Initialize z and u
z = nn.Parameter(x_admm.img.clone().detach()).to(device)
opt_z = torch.optim.Adam([z], lr=0.01)

u = torch.zeros_like(x_admm.img).to(device)

rho = 1e-6  # Penalty parameter
lambda_param = 1e2  # Weight for asymmetry loss

diffusion = GaussianDiffusion(T=1000, schedule='linear')
net.eval()
class_net.eval()


steps = 1000
inner_steps = 10
bar = tqdm.tqdm(range(steps))
losses = []
update_every = 200

target = torch.Tensor([0]).long().to(device)

for i in bar:
    # Select t
    t = steps - i
    #t = ((steps - i) + (steps - i) // 4 * math.cos(i / 50)) / steps * diffusion.T
    t = np.array([t]).astype(int)
    t = np.clip(t, 1, diffusion.T)

    # x-update
    sample_img = x_admm.encode()
    xt, epsilon = diffusion.sample(sample_img, t)
    t = torch.from_numpy(t).float().view(sample_img.shape[0])
    epsilon_pred = net(xt.float(), t.to(device))
    loss_denoise = F.mse_loss(epsilon_pred, epsilon)

    loss_x = loss_denoise + (rho / 2) * torch.norm(x_admm.img - z + u) ** 2

    opt_x.zero_grad()
    loss_x.backward()
    opt_x.step()

    # z-update
    sample_img_clipped_z = z  #torch.clamp(z, -1, 1)
    for _ in range(inner_steps):
        pred_class = class_net(sample_img_clipped_z)
        aux_loss = F.cross_entropy(pred_class, target)
        loss_z = 0.01*(steps-i)/steps * lambda_param * aux_loss + (rho / 2) * torch.norm(x_admm.img.detach() - sample_img_clipped_z + u) ** 2

        opt_z.zero_grad()
        loss_z.backward()
        opt_z.step()

    # u-update
    u = u + x_admm.img.detach() - sample_img_clipped_z.detach()

    # Logging
    total_loss = loss_x.item() + loss_z.item()
    losses.append(total_loss)
    if i % update_every == 0:
        bar.set_postfix({'Loss': np.mean(losses)})
        losses = []

    # Visualize sample
    if (i + 1) % steps == 0:
        with torch.no_grad():
            fig, ax = plt.subplots(1, 1, figsize=(5, 5))
            img_to_show = x_admm.encode()[0].detach().cpu().numpy().transpose([1, 2, 0])
            ax.imshow(img_to_show, vmin=-1, vmax=1)
            ax.set_title('Inferred sample')
            plt.show()
# Out:
# ...
# 100%|██████████| 1000/1000 [01:22<00:00, 12.10it/s, Loss=1.28]
